# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucia1009/TFG-Plataforma-para-la-prediccion-de-potencia-electrica-generada-en-parques-eolicos/blob/desarrollo/modelos/datos_variados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dash -q

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import plotly.graph_objects as go
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 9.4 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1=pd.read_csv('/content/drive/MyDrive/TFG/datos_variaciones/Report_ElValle_cada_minuto_sinteticos_con_esperas_transitorio_aa.csv', delimiter=";",decimal=".",skiprows = [1])
df2=pd.read_csv('/content/drive/MyDrive/TFG/datos_variaciones/Report_ElValle_cada_minuto_sinteticos_con_esperas_transitorio_ab.csv', delimiter=";",decimal=".",skiprows = [1])
df3=pd.read_csv('/content/drive/MyDrive/TFG/datos_variaciones/Report_ElValle_cada_minuto_sinteticos_con_esperas_transitorio_ac.csv', delimiter=";",decimal=".",skiprows = [1])
df4=pd.read_csv('/content/drive/MyDrive/TFG/datos_variaciones/Report_ElValle_cada_minuto_sinteticos_con_esperas_transitorio_ad.csv', delimiter=";",decimal=".",skiprows = [1])
df5=pd.read_csv('/content/drive/MyDrive/TFG/datos_variaciones/Report_ElValle_cada_minuto_sinteticos_con_esperas_transitorio_ae.csv', delimiter=";",decimal=".",skiprows = [1])

df=pd.concat([df1,df2,df3,df4,df5])

# %% [markdown]
# # Tratamiento de datos

# %%
df.head()
print(df.shape)

# Filtro para el régimen estacionario
datos_filtrado=df[(df['TIME'] % 600==540)]

print(datos_filtrado.shape)

#Reseteo el índice y quito la primera fila
datos_filtrado = datos_filtrado.reset_index(drop=True)
print(datos_filtrado.iloc[0]['TIME'])
print(datos_filtrado.iloc[1]['TIME'])

datos_filtrado=datos_filtrado.drop(0)
print(datos_filtrado.iloc[0]['TIME'], '\n')

#Obtener la dirección wd mímina y máxima de datos_filtrado
min=datos_filtrado['wd'].min()
max=datos_filtrado['wd'].max()
print(min, max)

datos_filtrado = datos_filtrado[datos_filtrado['wd'] >= 0]
datos_filtrado = datos_filtrado[datos_filtrado['wd'] < 360]
print(datos_filtrado.shape)
min=datos_filtrado['wd'].min()
max=datos_filtrado['wd'].max()
print(min, max, '\n')

# Obtener el mínimo y máximo de potencia
min=datos_filtrado['WF_Power'].min()
max=datos_filtrado['WF_Power'].max()
print(min, max)

datos_filtrado = datos_filtrado[datos_filtrado['WF_Power'] >= 0]
print(datos_filtrado.shape, '\n')

#Obtener el mínimo y máximo de velocidad de viento ws
min=datos_filtrado['ws'].min()
max=datos_filtrado['ws'].max()
print(min, max)

datos_filtrado = datos_filtrado[datos_filtrado['ws'] >= 0]
print(datos_filtrado.shape, '\n')

datos_filtrado.head()
# Out:
# (1000000, 165)
# (100000, 165)
# 540.0
# 1140.0
# 1140.0
#
# -15.0213314 372.700618
# (99363, 165)
# 0.0137177188 359.995667
#
# -0.000116567547 70053460.3
# (92619, 165)
#
# -3.02420751e-07 30.0000369
# (92600, 165)
#    TIME  TC1.T.Pg.signal[1]  TC2.T.Pg.signal[1]  TC3.T.Pg.signal[1]  \
# 1  1140          1256141.37          1256258.27          1254315.43
# 2  1740          1258355.96          1258355.97          1258360.59
# 3  2340          1190767.16          1190767.16          1190767.16
# 4  2940          1212111.16          1212111.16          1212111.16
# 5  3540          1191981.01          1191981.01          1191981.01
#
#    TC4.T.Pg.signal[1]  TC5.T.Pg.signal[1]  TC6.T.Pg.signal[1]  \
# 1          1254475.38          1256258.27          1119599.45
# 2          1102833.33          1258355.97          1237839.61
# 3          1190979.42          1190767.16          1190768.98
# 4          1212138.75          1212111.16          1212111.16
# ...

# %%
# Obtengo los distintos valores para cada setpoint

setpoints=datos_filtrado['WF_Power_SP'].unique()
print(setpoints)
print(len(setpoints))
print('type: ', type(setpoints))
# Out:
# [16663543.2 42690226.6 14844327.7 ... 41590025.8 72250076.  38639524.4]
# 2820
# type:  <class 'numpy.ndarray'>

# %%
def obtener_direcciones(df_filtrado, columnas):

  direcciones={}
  for i in range(0,360):
      # Separo los datos para cada dirección
      filtered_data = df_filtrado[(df_filtrado['wd'] <= i) & (df_filtrado['wd'] > (i - 1 ))]

      # Selecciono solo las columnas que me interesan
      selected_columns = filtered_data[columnas]

      direcciones[i]=selected_columns

  return direcciones

# %% [markdown]
# ---
#
# # Gráficas interactivas

# %%
"""Gráfica de viento y potencia para cada setpoint diferenciado por direcciones y sin ellas"""


app = Dash('app1')

app.layout = html.Div([

  dcc.Dropdown(setpoints, setpoints[0], id='potencia', clearable=False),

  dcc.Checklist(
          id='direccion',
          options=[{'label': 'Mostrar datos por dirección:', 'value': 'ver_dir'}],
          value=[]
      ),
    html.Div([
      "Direccion: ",
      dcc.Input(id='dir_1', value=258, type='number')
  ]),
  dcc.Graph(id='graph')
])


@app.callback(
    Output('graph', 'figure'),
    Input('dir_1', 'value'),
    Input('direccion', 'value'),
    Input('potencia', 'value'))
def update_output_div(dir1, direccion, potencia):

  datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]

 # Crear figura base
  fig = go.Figure()

  if 'ver_dir' in direccion:
    direcciones=obtener_direcciones(datos_limpios, ['ws', 'WF_Power', 'wd'])
    if dir1 in direcciones:
        fig.add_trace(go.Scatter(x=direcciones[dir1]['ws'], y=direcciones[dir1]['WF_Power'], mode='markers', marker=dict(color='blue')))

  else:

    fig.add_trace(go.Scatter(x=datos_limpios['ws'], y=datos_limpios['WF_Power'], mode='markers', marker=dict(color='blue')))

  fig.update_layout(
      title='Potencia vs velocidad general y por dirección',
      transition_duration=10,
      xaxis_title='Velocidad del viento (ws)',
      yaxis_title='Potencia del parque (WF_Power)'
  )

  return fig



if __name__ == '__main__':
    app.run_server(debug=True, port=8061)

# %%
"""Histograma de número de direcciones por cada setpoint"""

app = Dash('app1')

app.layout = html.Div([
    dcc.Dropdown(setpoints, setpoints[0], id='potencia', clearable=False),
    dcc.Graph(id='graph')
])


@app.callback(
    Output('graph', 'figure'),
    Input('potencia', 'value'))
def update_output_div( potencia):

  datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]


  # Crear figura base
  fig = go.Figure()

  fig.add_histogram(
    x=datos_limpios['wd'],
    nbinsx=360,
    xbins=dict(start=0, end=360, size=1)
)

  fig.update_layout(
      title='Número de datos de cada dirección',
      transition_duration=10,
      xaxis_title='Direcciones de viento (wd)',
      yaxis_title='Número de veces que aparece'
  )

  return fig



if __name__ == '__main__':
    app.run_server(debug=True, port=8062)

# %%
"""Histograma de número de velocidades por cada setpoint"""

app = Dash('app1')

app.layout = html.Div([
    dcc.Dropdown(setpoints, setpoints[0], id='potencia', clearable=False),
    dcc.Graph(id='graph')
])


@app.callback(
    Output('graph', 'figure'),
    Input('potencia', 'value'))
def update_output_div( potencia):

  datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]


  # Crear figura base
  fig = go.Figure()

  fig.add_histogram(
    x=datos_limpios['ws'],
  )

  fig.update_layout(
      title='Número de datos de cada velocidad',
      transition_duration=10,
      xaxis_title='Velocidades de viento (ws)',
      yaxis_title='Número de veces que aparece',
      xaxis_range=[0, 30]
  )

  return fig



if __name__ == '__main__':
    app.run_server(debug=True, port=8063)

# %% [markdown]
# ---
#
#
#
# # Gráficas para sólo 1 dirección
# ####Caso con muchas direcciones con más de 2 puntos
# Setpoint = 63337430.8 W

# %%
"""Gráfica viento potencia para todas las direcciones"""

potencia=setpoints[2423]
datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]

fig = go.Figure()


fig.add_trace(go.Scatter(x=datos_limpios['ws'], y=datos_limpios['WF_Power'], mode='markers', marker=dict(color='blue')))


fig.update_layout(
    transition_duration=10,
    xaxis_title='Velocidad del viento (ws)',
    yaxis_title='Potencia del parque (WF_Power)'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""Gráfica viento potencia para la dirección de más puntos"""

potencia=setpoints[2423]
dir1=233
dir2=1
compara=['ver_dir2']


datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]

direcciones=obtener_direcciones(datos_limpios, ['ws', 'WF_Power', 'wd'])

for i in range(0,360):
  if len(direcciones[i])>2:
    print(i)

# Crear figura base
fig = go.Figure()

if dir1 in direcciones:
  fig.add_trace(go.Scatter(x=direcciones[dir1]['ws'], y=direcciones[dir1]['WF_Power'], mode='markers', marker=dict(color='blue')))

if 'ver_dir2' in compara and dir2 in direcciones:
  fig.add_trace(go.Scatter(x=direcciones[dir2]['ws'], y=direcciones[dir2]['WF_Power'], mode='markers', marker=dict(color='red')))

fig.update_layout(
    transition_duration=10,
    xaxis_title='Velocidad del viento (ws)',
    yaxis_title='Potencia del parque (WF_Power)'
)

fig.show()
# Out:
# 227
# 233
# 236
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""histograma de la concentracion de valores de direcciones"""

potencia=setpoints[2423]

# datos_limpios = datos_filtrado
datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]


# Crear figura base
fig = go.Figure()

# Histograma con un bin por cada grado 0-359
fig.add_histogram(
    x=datos_limpios['wd'],
    nbinsx=360,  # Ensure 360 bins for 0-359 degrees
    xbins=dict(start=0, end=360, size=1)  # Define bin size and range
)

fig.update_layout(
    transition_duration=10,
    xaxis_title='Direcciones de viento (wd)',
    yaxis_title='Número de veces que aparece'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""histograma de la concentracion de valores de velocidades"""

potencia=setpoints[2423]

# datos_limpios = datos_filtrado
datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]


# Crear figura base
fig = go.Figure()

fig.add_histogram(
  x=datos_limpios['ws'],
)

fig.update_layout(
    title='Número de datos de cada velocidad',
    transition_duration=10,
    xaxis_title='Velocidades de viento (ws)',
    yaxis_title='Número de veces que aparece',
    xaxis_range=[0, 30]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---
#
#
#
# ---
# ### Auxiliar: Cuenta de datos de dirección con más de 1 valor para cada setpoint

# %%
# suma_2=[]
# for potencia in setpoints:
#   datos_limpios = datos_filtrado[datos_filtrado['WF_Power_SP'] == potencia]
#   direcciones=obtener_direcciones(datos_limpios, ['ws', 'WF_Power', 'wd'])

#   sum=0
#   for j in range(0,360):
#     if len(direcciones[j])>1:
#       sum=sum+1
#   suma_2.append(sum)
# print(suma_2)

# Salida:
# [8, 4, 8, 2, 9, 5, 2, 10, 6, 8, 8, 8, 13, 0, 9, 7, 5, 8, 9, 7, 6, 8, 9, 11, 8, 8, 5, 9, 5, 7, 6, 3, 9, 7, 10, 6, 11, 9, 6, 8, 5, 3, 11, 3, 12, 12, 4, 10, 8, 7, 8, 3, 10, 3, 6, 7, 6, 13, 8, 10, 4, 4, 11, 9, 0, 10, 9, 9, 11, 5, 10, 5, 8, 9, 4, 9, 10, 11, 10, 2, 0, 7, 6, 11, 12, 2, 8, 4, 9, 11, 6, 7, 6, 2, 11, 7, 7, 7, 8, 9, 2, 6, 7, 4, 8, 7, 6, 6, 10, 7, 2, 8, 5, 9, 9, 4, 9, 5, 9, 11, 8, 8, 7, 8, 11, 9, 11, 11, 4, 9, 4, 5, 7, 9, 9, 0, 7, 7, 10, 11, 2, 12, 9, 2, 5, 3, 8, 8, 5, 8, 7, 12, 9, 9, 11, 3, 9, 10, 7, 8, 3, 4, 7, 10, 12, 5, 6, 7, 1, 9, 5, 7, 9, 6, 11, 11, 9, 11, 5, 8, 5, 8, 9, 3, 8, 6, 8, 8, 5, 9, 2, 8, 11, 8, 10, 1, 6, 7, 6, 9, 8, 6, 5, 1, 9, 7, 9, 9, 2, 11, 2, 7, 6, 7, 13, 10, 9, 11, 3, 7, 1, 10, 10, 5, 7, 1, 7, 8, 6, 7, 7, 7, 6, 3, 10, 5, 11, 8, 0, 1, 10, 3, 8, 6, 9, 9, 2, 7, 9, 2, 7, 5, 9, 12, 1, 9, 8, 6, 8, 2, 10, 2, 8, 6, 3, 9, 11, 7, 5, 4, 10, 2, 12, 9, 7, 8, 3, 9, 10, 3, 7, 8, 12, 10, 5, 8, 6, 11, 8, 7, 6, 7, 8, 0, 8, 7, 8, 7, 10, 7, 6, 12, 4, 6, 0, 7, 5, 13, 1, 6, 6, 3, 11, 10, 9, 9, 11, 12, 1, 6, 6, 1, 10, 12, 11, 8, 8, 9, 1, 5, 5, 3, 8, 8, 7, 8, 2, 9, 11, 10, 7, 9, 9, 3, 8, 10, 6, 10, 3, 6, 8, 2, 11, 9, 11, 8, 2, 10, 4, 8, 7, 8, 8, 3, 9, 10, 4, 10, 8, 8
, 4, 14, 10, 7, 6, 0, 2, 8, 10, 7, 6, 11, 12, 11, 11, 8, 8, 9, 3, 11, 10, 8, 10, 5, 6, 10, 11, 8, 6, 8, 7, 4, 12, 4, 6, 7, 10, 12, 10, 6, 6, 2, 9, 5, 10, 10, 10, 8, 6, 6, 8, 5, 10, 10, 9, 8, 3, 7, 5, 7, 6, 0, 7, 10, 7, 8, 5, 9, 10, 5, 7, 4, 1, 0, 8, 4, 6, 8, 1, 10, 3, 11, 9, 2, 7, 3, 10, 6, 7, 11, 9, 9, 7, 2, 8, 2, 8, 7, 11, 11, 4, 8, 6, 4, 10, 4, 10, 11, 4, 11, 8, 10, 9, 2, 9, 9, 8, 8, 9, 10, 2, 6, 5, 4, 9, 11, 9, 8, 6, 10, 8, 7, 6, 0, 2, 10, 2, 6, 6, 4, 10, 6, 6, 5, 9, 9, 2, 7, 10, 9, 10, 4, 10, 9, 9, 7, 6, 7, 8, 6, 8, 2, 9, 5, 9, 12, 10, 10, 10, 4, 11, 4, 4, 7, 8, 11, 6, 9, 10, 7, 8, 5, 8, 9, 6, 8, 5, 7, 5, 2, 10, 6, 9, 10, 12, 10, 6, 6, 8, 4, 8, 9, 6, 7, 6, 9, 3, 10, 9, 8, 11, 3, 9, 9, 2, 0, 8, 3, 8, 8, 5, 12, 7, 6, 7, 3, 9, 2, 9, 8, 10, 10, 5, 8, 6, 3, 11, 8, 6, 5, 2, 8, 3, 9, 7, 5, 9, 7, 7, 9, 2, 10, 3, 6, 6, 1, 12, 1, 7, 9, 8, 11, 2, 5, 7, 4, 11, 4, 8, 9, 4, 11, 4, 6, 4, 2, 11, 4, 10, 6, 9, 7, 11, 6, 7, 4, 10, 10, 6, 6, 9, 10, 10, 9, 10, 3, 9, 9, 6, 9, 7, 8, 4, 0, 7, 11, 4, 11, 5, 7, 7, 5, 8, 9, 7, 5, 2, 8, 4, 7, 6, 8, 7, 10, 12, 11, 2, 11, 3, 11, 8, 8, 9, 3, 0, 9, 14, 3, 8, 0, 7, 6, 6, 10, 3, 0, 5, 5, 4, 8, 8, 10, 9, 4, 8, 5, 8, 7, 5, 10, 9, 7, 8, 4, 9, 3, 5, 7, 4, 5, 5, 3, 9, 8, 9, 4, 9, 12, 3, 10, 4, 0, 8, 6, 11, 11, 3, 11, 12, 2, 9, 7, 9, 8, 7, 10, 3, 8, 8, 2, 10]

# %%
# for i in range(len(suma_2)):
#   if suma_2[i] > 13:
#     print(suma_2[i])
#     print(i)
#     print(setpoints[i], '\n')

# # Contar cuántas instancias hay con la misma suma
# for i in range(15):
#   print(i, suma_2.count(i))


"""
Salida:

14
2423
63337430.8

14
2758
29033323.0

0 55
1 43
2 122
3 163
4 194
5 211
6 274
7 313
8 391
9 419
10 335
11 200
12 88
13 13
14 2
"""
# Out:
# '\nSalida:\n\n14\n2423\n63337430.8\n\n14\n2758\n29033323.0\n\n0 55\n1 43\n2 122\n3 163\n4 194\n5 211\n6 274\n7 313\n8 391\n9 419\n10 335\n11 200\n12 88\n13 13\n14 2\n'
